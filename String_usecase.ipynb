# %% [markdown]
# <a href="https://colab.research.google.com/github/NivethaAshokkumarG/Ecommerce-Sales-Analysis/blob/main/String_usecase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# """
# ## **Case Study – Email Username Generator**
#
# **Instructions:**
#
# • Create variables: full_name, domain_name
#
# • Take input from the user using input() function
#
# • Convert full_name into lowercase using lower()
#
# • Remove spaces in name and replace with dot using replace()
#
# • Split full_name using split() function
#
# • Join name parts using join() function if needed
#
# • Create email in format: name@domain
#
# • Display only Full Name and Generated Email
#
# • Use print() and f-string for output display
#
# """

# %%
full_name=input("Enter you Full_Name")
domain_name = input("Enter your Domain Name")

print(full_name)
print(domain_name)

new_name = full_name.lower()
print(new_name)

email_name = new_name.replace(" ", ".")

split_name = full_name.split()
print(split_name)

new_join = "**".join(full_name)
print(new_join)

e_name = email_name + "@" + domain_name

print(f"Full Name :{full_name.upper()}")
print(f"Generated_Mail :{e_name}")
# Out:
# Enter you Full_NameNivetha Ashok Kumar
# Enter your Domain NameSQL
# Nivetha Ashok Kumar
# SQL
# nivetha ashok kumar
# ['Nivetha', 'Ashok', 'Kumar']
# N**i**v**e**t**h**a** **A**s**h**o**k** **K**u**m**a**r
# Full Name :NIVETHA ASHOK KUMAR
# Generated_Mail :nivetha.ashok.kumar@SQL

# %% [markdown]
# """
# ## **Case Study – Student ID Card Generator**
#
# **Instructions:**
#
# • Create variables: student_name, roll_number, department
#
# • Take input from the user using input() function
#
# • Convert student_name and department into uppercase using upper()
#
# • Extract first 4 letters of student_name and department using slicing
#
# • Create Student ID by combining name, department, and roll number
#
# • Display Name, Department, Roll Number, and Student ID only
#
# • Use print() and f-string for output display
# """

# %%
student_name = input("Enter the student_Name")
roll_numer= input("Enter your Roll_Number")
Department = input("Enter your Department_Name")

print(student_name.upper())
print(roll_numer.upper())
print(Department.upper())


print(student_name[:4])
print(roll_numer[:4])
print(Department[:4])


student_iD = student_name + " " + roll_numer +" " + Department

print(f"Name :{student_name} \n")
print(f"Department:{Department}\n")
print(f"student_iD : {student_iD}n")
# Out:
# Enter the student_NameNivetha Ashok
# Enter your Roll_Number180314
# Enter your Department_NameInfo Tech
# NIVETHA ASHOK
# 180314
# INFO TECH
# Nive
# 1803
# Info
# Name :Nivetha Ashok
#
# Department:Info Tech
#
# student_iD : Nivetha Ashok 180314 Info Techn
